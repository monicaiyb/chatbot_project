# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
bot = ChatBot("Uttam")
trainer = ListTrainer(bot)

trainer.train(
    [
     'Hi',
     'Hello',
     'How are you?',
     'I am fine thank you. What about you?',
     'I am also fine',
     'Ki Blood',
     'Oli Gumite?'
     'Nice to hear that',
     'What is your name?',
     'My name is Nsereko',
     'Thank you',
     'You are most welcome'
    ]
)
# Out:
# List Trainer: 100%|█████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 24898.73it/s]

# %%
name = input("Enter your name: ")

while True:
  try:
    print(name,end="-->") 
    user_input= input()
    if user_input=='bye':
      break
    bot_response = bot.get_response(user_input)

    print("BOT-->",bot_response)
    print("")

  except(KeyboardInterrupt, EOFError, SystemExit ):
    break
# Out:
# Enter your name:  mo
# mo-->
#  monica
# BOT--> You are most welcome
#
# mo-->
#  yes
# BOT--> monica
#
# mo-->
#  hfr
# BOT--> Oli Gumite?Nice to hear that
#
# mo-->
